# %% [markdown]
# # Nombre:Fanny Gutama    Tema:Calidad del vino

# %% [markdown]
# Para resolver este ejercicio utilizamos el metodo de jacacard que calcula la distancia entre dos vectores aplicando la siguiente formula
